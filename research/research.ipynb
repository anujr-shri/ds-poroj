# %%
import os
os.environ["MLFLOW_TRACKING_URI"] = "https://dagshub.com/anujr-shri/ds-poroj.mlflow"
os.environ["username"] = "anujr-shri"
os.environ["password"] = "385225323cff6f7f9dc0e2cd4b3211fdd7ca6bf7"
